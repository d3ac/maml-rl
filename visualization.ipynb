# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Train

# %%
data = pd.read_excel('train.xlsx')
data = np.array(data)
plt.plot(data)
plt.xlabel('iteration')
plt.ylabel('return')
plt.title('train')
# Out:
# Text(0.5, 1.0, 'train')

# %%
data = pd.read_excel('valid.xlsx')
data = np.array(data)
plt.plot(data)
plt.xlabel('iteration')
plt.ylabel('return')
plt.title('valid')
# Out:
# Text(0.5, 1.0, 'valid')

# %% [markdown]
# ## Test

# %%
data = np.load('output/results.npz')
train = data['train_returns']
test =  data['valid_returns']
print(f'train: {train}, mean:{np.mean(train)}\n')
print(f'test: {test}, mean{np.mean(test)}\n')
# Out:
# train: [-103.136795 -101.47964  -107.69541  -105.34383   -99.601456 -111.559784
#  -114.219864  -90.597404 -111.50761  -110.990585], mean:-105.61323547363281
#
# test: [-102.07726   -99.063545 -109.88163  -109.81567  -100.25393  -112.623985
#  -113.77829   -89.4345   -112.351295 -113.59424 ], mean-106.28743743896484
